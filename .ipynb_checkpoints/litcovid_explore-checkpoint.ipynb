# %% [markdown]
# Use the LitCovid dataset
#
# Downloaded test.csv, train.csv, valid.csv from https://ftp.ncbi.nlm.nih.gov/pub/lu/LitCovid/topic_tagger/
#
# Inputs: title and abstract
#
# Model: CNN (performed best for dataset per Dr. Chen)
#
# Output: classification of this study's label
#
# Models
#
# - Baseline model: Naive Bayes
#
# - CNN
#
# - RNN (or another alternative model)

# %% [markdown]
# ## Steps
#
# ### Clean the data
#
# - Combine test.csv, valid.csv, and train.csv into a single csv and re-split
#
# ### EDA
#
# - How are words clustering?
#
# ### Preprocess
#
# - Tokenize words
#
# - Generate word embeddings (word2vec)
#
# ### Train models
#
# - Train Naive Bayes (baseline model), CNN (our model), RNN (or another alternative model)
#
# ### Quantitative evaluation of each model
#
# - Multilabel classifiers use a [confusion matrix for each label](https://towardsdatascience.com/evaluating-multi-label-classifiers-a31be83da6ea)
#
# - Generate an AUC curve
#
# - tSNE with clusters - compare between predicted vs. actual

# %%
import pandas as pd

# %%
test = pd.read_csv('data/test.csv')

# %%
test.head()
# Out:
#        pmid                  journal  \
# 0  33062853            J Patient Exp
# 1  32370923           J Arthroplasty
# 2  32592837  Diabetes Res Clin Pract
# 3  32914188                Phys Ther
# 4  32987222           Psychiatry Res
#
#                                                title  \
# 0  Why Companion Animals Are Beneficial During CO...
# 1  Disruption of Arthroplasty Practice in an Orth...
# 2        COVID-19 and diabetes from IDF MENA region.
# 3  Clinical Update for Physical Therapists: Coagu...
# 4  Lockdown, quarantine measures, and social dist...
#
#                                             abstract  \
# 0  Companion animals and pets can be helpful duri...
# 1  BACKGROUND: The Coronavirus disease 2019 (COVI...
# 2  The whole world are facing the current COVID-1...
# 3  Physical therapists have a unique role in both...
# 4  The COVID-19 pandemic is suggested to have a n...
#
#                                             keywords       label  \
# ...
